# %%
import healpy as hp
import numpy as np
from DS_Planck_Unet import val_pix
from DS_Planck_Unet import test_pix

# %%
a = np.zeros(hp.nside2npix(2))
a[val_pix] = 1
a[test_pix] = 2
hp.mollview(a, nest=True, title='val and test area')
