# %%
import numpy as np
import pandas as pd
import os
from astropy.coordinates import SkyCoord
from astropy import units as u
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
from DS_data_transformation import get_cat_name
# %config InlineBackend.figure_format = 'retina'

# %%
def n_found_in_cats(gt_df, det_df, rad):
    ans = 0
    det_sc = SkyCoord(ra=np.array(det_df['RA']) *u.degree, dec=np.array(det_df['DEC'])*u.degree, frame='icrs')
    for i in range(len(gt_df)):
        ra, dec = gt_df.loc[i, ['RA', 'DEC']]
        sc_gt = SkyCoord(ra=ra*u.degree, dec=dec*u.degree, frame='icrs')
        
        angle = sc_gt.separation(det_sc)
        ans += np.count_nonzero(angle.degree <= rad)
    return ans

# %%
def n_src2rad(det_cat_file, true_cat_file, rads=[0, 1600/3600, 100/3600]): 
    n_src = []
    res_src = []
    
    tr_df = pd.read_csv(true_cat_file)
    det_df = pd.read_csv(det_cat_file)
    
    
    for rad in tqdm(np.arange(*rads)):
        n_src.append(n_found_in_cats(tr_df, det_df, rad))
        if len(n_src) > 1:
            res_src.append(n_src[-1] - n_src[-2])
        else:
            res_src.append(n_src[-1])
        
    x = np.arange(*rads)
    x += rads[-1]/2
    x *= 3600
    return x, res_src

# %%
dirname = '/home/rt2122/Data/original_catalogs/csv/'
true_cats = next(os.walk(dirname))[-1]
true_cats = {os.path.splitext(os.path.basename(s))[0] : os.path.join(dirname, s) for s in true_cats}
true_cats['PSZ2(z)'] = '/home/rt2122/Data/clusters/planck_z.csv'
true_cats['eROSITA'] = '/home/rt2122/Data/SRGz/clusters/clusters1_b20_edit.csv'
#det_cat = '/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv'
det_cat = '/home/rt2122/Data/original_catalogs/csv/PSZ2.csv' 
n_src = {}

# %%
selected = ['PSZ2(z)', 'MCXC', 'ACT', 'eROSITA']
x = None
for cat in tqdm(selected):
    x, cur = n_src2rad(det_cat, true_cat_file=true_cats[cat], rads=[0, 1600/3600, 100/3600])
    n_src[cat] = cur
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e9204fec956d> in <module>
#       3 x = None
#       4 for cat in tqdm(selected):
# ----> 5     x, cur = n_src2rad(det_cat, true_cat_file=true_cats[cat], rads=[0, 1600/3600, 100/3600])
#       6     n_src[cat] = cur
#
# <ipython-input-3-0cd90f2aa371> in n_src2rad(det_cat_file, true_cat_file, rads)
#       8
#       9     for rad in np.arange(*rads):
# ---> 10         n_src.append(n_found_in_cats(tr_df, det_df, rad))
#      11         if len(n_src) > 1:
#      12             res_src.append(n_src[-1] - n_src[-2])
#
# <ipython-input-2-6624cbfe4a1c> in n_found_in_cats(gt_df, det_df, rad)
#       6         sc_gt = SkyCoord(ra=ra*u.degree, dec=dec*u.degree, frame='icrs')
#       7
# ----> 8         angle = sc_gt.separation(det_sc)
#       9         ans += np.count_nonzero(angle.degree <= rad)
#      10     return ans
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/coordinates/sky_coordinate.py in separation(self, other)
#     849
#     850         # Get the separation as a Quantity, convert to Angle in degrees
# --> 851         sep = angular_separation(lon1, lat1, lon2, lat2)
#     852         return Angle(sep, unit=u.degree)
#     853
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/coordinates/angle_utilities.py in angular_separation(lon1, lat1, lon2, lat2)
#     699     cdlon = np.cos(lon2 - lon1)
#     700     slat1 = np.sin(lat1)
# --> 701     slat2 = np.sin(lat2)
#     702     clat1 = np.cos(lat1)
#     703     clat2 = np.cos(lat2)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/coordinates/angles.py in __array_ufunc__(self, *args, **kwargs)
#     539     # Any calculation should drop to Angle
#     540     def __array_ufunc__(self, *args, **kwargs):
# --> 541         results = super().__array_ufunc__(*args, **kwargs)
#     542         return _no_angle_subclass(results)
#     543
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py in __array_ufunc__(self, function, method, *inputs, **kwargs)
#     475
#     476         # Call our superclass's __array_ufunc__
# --> 477         result = super().__array_ufunc__(function, method, *arrays, **kwargs)
#     478         # If unit is None, a plain array is expected (e.g., comparisons), which
#     479         # means we're done.
#
# KeyboardInterrupt:

# %%
cat = 'eROSITA'
x, cur = n_src2rad(det_cat, true_cat_file=true_cats[cat], rads=[0, 1600/3600, 100/3600])
n_src[cat] = cur
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
def plot_n_src(x, n_src_arr, rads=[0, 1600/3600, 100/3600], figsize=(8, 6), cat='', vline=[400/3600, 1000/3600, 1600/3600],
              logscale=False, ylabel='$N_{src}$ / radius'):
    _, ax = plt.subplots(1, 1, figsize=figsize)
    
    ax.plot(x, n_src_arr/np.arange(*rads))
    #ax.plot(x, n_src_arr/x)
    if logscale:
        plt.yscale('log')
    
    ax.set_xlabel('radius, \'\'  ' + cat)
    ax.set_ylabel(ylabel)
    
    ax.grid(True, axis='both', which='major', linestyle=':')
    ax.grid(True, axis='both', which='minor', alpha=0.2, linestyle=':') 
    
    for v, c in zip(vline, 'rcc'):
        line = ax.axvline(3600 * v, c=c)
        line.set_label(str(int(v * 3600)) + ' \'\'')
    ax.legend()

# %%
rads=[0, 1600/3600, 50/3600]
rads1=[0, 1600/3600, 100/3600]

# %%
plot_n_src(x, n_src['PSZ2(z)'], cat='PSZ2(z)', rads=rads1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a5060f268c21> in <module>
# ----> 1 plot_n_src(x, n_src['PSZ2(z)'], cat='PSZ2(z)', rads=rads1)
#
# NameError: name 'x' is not defined

# %%
cat='MCXC'
plot_n_src(x, n_src[cat], cat=cat, rads=rads1)
# Out:
# <ipython-input-12-b3a4c19da439>:5: RuntimeWarning: invalid value encountered in true_divide
#   ax.plot(x, n_src_arr/np.arange(*rads))

# %%
cat='ACT'
plot_n_src(x, n_src[cat], cat=cat, rads=rads1)
# Out:
# <ipython-input-12-b3a4c19da439>:5: RuntimeWarning: invalid value encountered in true_divide
#   ax.plot(x, n_src_arr/np.arange(*rads))

# %%
cat='eROSITA'
plot_n_src(x, n_src[cat], cat=cat, rads=rads1)
# Out:
# <ipython-input-6-b3a4c19da439>:5: RuntimeWarning: invalid value encountered in true_divide
#   ax.plot(x, n_src_arr/np.arange(*rads))

# %%
for cat in n_src:
    np.save('/home/rt2122/Data/cur/n_src2rad/{}_{}_{}_{}.npy'.format(cat, *rads), n_src)

# %%
list(n_src)
# Out:
# ['PSZ2(z)', 'MCXC', 'ACT']
