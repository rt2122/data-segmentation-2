# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %%
def this_ax2(ax):
    ax.grid()
    ax.legend()

# %%
def show_precision_recall(ax, pixname, show_basic, selected=['all_true', 'eROSITA', 'PSZ2(z)']):
    base_cat_name = 'SZ_cat(basic)'
    al_cat_name = 'SZ_cat(AL)'
    recalls = {al_cat_name : pd.read_csv('./check/all_found34_recall_max_pred_pix{}.csv'.format(pixname), index_col='max_pred'),
         base_cat_name : pd.read_csv('./check/pz_rot28_recall_max_pred_pix{}.csv'.format(pixname), index_col='max_pred')
    }

    for c, recall_prm, prec_prm in zip('krb', ['all_true', 'eROSITA', 'PSZ2(z)'], 
                                       ['precision', 'precision_eROSITA', 'precision_PSZ2(z)']):
        if not (recall_prm in selected):
            continue
        for name_cat, st in zip(recalls, ['-', '--']):
            if not show_basic and name_cat == base_cat_name:
                continue
                
            df = recalls[name_cat]
            s, = ax.plot(df[recall_prm], df[prec_prm], c=c, linestyle=st)
            if name_cat == al_cat_name:
                s.set_label(recall_prm + ' ' + name_cat + ' ' + pixname)
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')
    this_ax2(ax)

_, ax = plt.subplots(1, 1, figsize=(8, 6))
show_precision_recall(ax, '41', True, selected=['all_true', 'PSZ2(z)'])

# %%
_, ax = plt.subplots(1, 1, figsize=(8, 6))
show_precision_recall(ax, 'e', True)
