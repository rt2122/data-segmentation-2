# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %%
def this_ax2(ax):
    ax.grid()
    ax.legend()

# %%
def show_precision_recall(ax, pixname, show_basic, selected=['all_true', 'eROSITA', 'PSZ2(z)'], brcat_mode=False, gen_mode=False, 
                          colors='krb', alpha=1, linestyles=['-', '--']):
    base_cat_name = 'SZ_cat(basic)'
    al_cat_name = 'SZ_cat(AL)'
    recalls = {al_cat_name : pd.read_csv('./check/all_found34_recall_max_pred_pix{}.csv'.format(pixname), index_col='max_pred'),
         base_cat_name : pd.read_csv('./check/pz_rot28_recall_max_pred_pix{}.csv'.format(pixname), index_col='max_pred')
    }
    if brcat_mode:
        recalls = {'brcat' : pd.read_csv('./check/brcat_recall_max_pred_pix{}.csv'.format(pixname), index_col='max_pred')}
    if gen_mode:
        recalls = {'gen' : pd.read_csv('./check/gen_recall_max_pred_pix{}.csv'.format(pixname), index_col='max_pred')}

    for c, recall_prm, prec_prm in zip(colors, ['all_true', 'eROSITA', 'PSZ2(z)'], 
                                       ['precision', 'precision_eROSITA', 'precision_PSZ2(z)']):
        if not (recall_prm in selected):
            continue
        for name_cat, st in zip(recalls, linestyles):
            if not show_basic and name_cat == base_cat_name:
                continue
                
            df = recalls[name_cat]
            s, = ax.plot(df[recall_prm], df[prec_prm], c=c, linestyle=st, alpha=alpha)
            if name_cat != base_cat_name:
                s.set_label(recall_prm + ' ' + name_cat + ' ' + pixname)
    ax.set_xlabel('Recall')
    ax.set_ylabel('Precision')

_, ax = plt.subplots(1, 1, figsize=(8, 6))
show_precision_recall(ax, '41', True, selected=['all_true'], colors='k')

show_precision_recall(ax, 'e', True, selected=['eROSITA'], colors='br')

show_precision_recall(ax, '41', True, selected=['all_true'], brcat_mode=True, colors='k', alpha=1, linestyles=[':'])

show_precision_recall(ax, 'e', True, selected=['eROSITA'], brcat_mode=True, colors='br', alpha=1, linestyles=[':'])

show_precision_recall(ax, '41', True, selected=['all_true'], gen_mode=True, colors='k', alpha=0.5)

show_precision_recall(ax, 'e', True, selected=['eROSITA'], gen_mode=True, colors='br', alpha=0.5)
this_ax2(ax)

# %%
_, ax = plt.subplots(1, 1, figsize=(8, 6))
show_precision_recall(ax, '41', True, selected=['all_true'], gen_mode=True, colors='k', alpha=0.5)

show_precision_recall(ax, 'e', True, selected=['eROSITA'], gen_mode=True, colors='br', alpha=0.5)
this_ax2(ax)

# %%
_, ax = plt.subplots(1, 3, figsize=(24, 6))
pixname='6'
selected = ['all_true', 'eROSITA']
show_precision_recall(ax[0], pixname, True, selected=selected, colors='kr')
show_precision_recall(ax[0], pixname, True, selected=selected, brcat_mode=True, colors='kr', alpha=1, linestyles=[':'])
show_precision_recall(ax[0], pixname, True, selected=selected, gen_mode=True, colors='kr', alpha=0.5)
this_ax2(ax[0])
pixname='38'
selected = ['all_true', 'eROSITA']
show_precision_recall(ax[1], pixname, True, selected=selected, colors='kr')
show_precision_recall(ax[1], pixname, True, selected=selected, brcat_mode=True, colors='kr', alpha=1, linestyles=[':'])
show_precision_recall(ax[1], pixname, True, selected=selected, gen_mode=True, colors='kr', alpha=0.5)
this_ax2(ax[1])
pixname='e'
selected = ['all_true', 'eROSITA']
show_precision_recall(ax[2], pixname, True, selected=selected, colors='kr')
show_precision_recall(ax[2], pixname, True, selected=selected, brcat_mode=True, colors='kr', alpha=1, linestyles=[':'])
show_precision_recall(ax[2], pixname, True, selected=selected, gen_mode=True, colors='kr', alpha=0.5)
this_ax2(ax[2])
