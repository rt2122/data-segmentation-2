# %%
import numpy as np
import pandas as pd
import os
from DS_models_stat import cut_cat
from DS_Planck_Unet import val_pix, west_val, east_val
from astropy.coordinates import SkyCoord
from astropy import units as u
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt
# %config InlineBackend.figure_format = 'retina'

# %%
det_cat6 = cut_cat(pd.read_csv('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv'), big_pix=[6])
true_cat6 = cut_cat(pd.read_csv('/home/rt2122/Data/SRGz/clusters/clusters1_east_val_edit.csv'), big_pix=[6])
det_cat38 = cut_cat(pd.read_csv('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv'), big_pix=[38])
true_cat38 = cut_cat(pd.read_csv('/home/rt2122/Data/SRGz/clusters/clusters1_east_val_edit.csv'), big_pix=[38])
true_cat6 = true_cat6.rename(columns={'flux_05-20' : 'flux'})
true_cat38 = true_cat38.rename(columns={'flux_05-20' : 'flux'})

# %%
def match_prm(det_cat, true_cat, match_dist=5/60, prms=[]):
    det_sc = SkyCoord(ra=np.array(det_cat['RA'])*u.degree, dec=np.array(det_cat['DEC'])*u.degree, frame='icrs')
    true_sc = SkyCoord(ra=np.array(true_cat['RA'])*u.degree, dec=np.array(true_cat['DEC'])*u.degree, frame='icrs')
    
    idx, d2d, _ = det_sc.match_to_catalog_sky(true_sc)
    matched = d2d.degree < match_dist
    det_cat['found'] = False
    det_cat.loc[matched, 'found'] = True
    det_cat['tRA'] = np.nan
    det_cat['tDEC'] = np.nan
    true_cat = true_cat.rename(columns={'RA' : 'tRA', 'DEC' : 'tDEC'})
    
    for prm in prms + ['tRA', 'tDEC']:
        det_cat[prm] = 0
        det_cat[prm].iloc[matched] = np.array(true_cat[prm].iloc[idx[matched]])
    return det_cat

# %%
det_cat6 = match_prm(det_cat6, true_cat6, match_dist=400/3600, prms=['flux'])
det_cat38 = match_prm(det_cat38, true_cat38, match_dist=400/3600, prms=['flux'])

# %%
det_cat6 = det_cat6[det_cat6['found']]
det_cat6.index = np.arange(len(det_cat6))
det_cat38 = det_cat38[det_cat38['found']]
det_cat38.index = np.arange(len(det_cat38))

# %%
_, ax = plt.subplots(1, 1, figsize=(10, 10))
s = ax.scatter(det_cat6['max_pred'], det_cat6['flux'], c='b')
s.set_label('objects 6')
l, = ax.plot(mean_max_pred, mean_flux6, c='r')
l.set_label('mean line 6')
s = ax.scatter(det_cat38['max_pred'], det_cat38['flux'], c='c')
s.set_label('objects 38')
l, = ax.plot(mean_max_pred, mean_flux38, c='k')
l.set_label('mean line 38')
ax.set_xlabel('max_pred')
ax.set_ylabel('flux')
ax.legend()
ax.grid()
plt.yscale('log')
plt.show()

# %%
max_pred_prm = np.arange(0, 1.1, 0.1)
mean_max_pred = (max_pred_prm[:-1] + max_pred_prm[1:])/2
mean_max_pred
# Out:
# array([0.05, 0.15, 0.25, 0.35, 0.45, 0.55, 0.65, 0.75, 0.85, 0.95])

# %%
mean_flux6 = []
mean_flux38 = []
for i in range(len(max_pred_prm) - 1):
    st = max_pred_prm[i]
    en = max_pred_prm[i + 1]
    matched = np.logical_and( st<= det_cat6['max_pred'], det_cat6['max_pred'] < en)
    mean_flux6.append(det_cat6['flux'][matched].mean())
    matched = np.logical_and( st<= det_cat38['max_pred'], det_cat38['max_pred'] < en)
    mean_flux38.append(det_cat38['flux'][matched].mean())
