# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from astropy.coordinates import SkyCoord
from astropy import units as u
from DS_models_stat import cut_cat
from DS_Planck_Unet import west_val, east_val
# %config InlineBackend.figure_format = 'retina'

# %%
det_cats = {
    'pz_rot28' : pd.read_csv('/home/rt2122/Data/detected_cats/full_pz_rot28_thr0.1_step8_no_fn.csv'),
    'pz_act_found2_22' : pd.read_csv('/home/rt2122/Data/detected_cats/full_pz_act_found2_22_thr0.1_step8_no_fn.csv'),
    'pz_all_found34' : pd.read_csv('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv')
}

# %%
true_cats = {
    'planck_z' : pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv'),
    'MCXC' : pd.read_csv('/home/rt2122/Data/original_catalogs/csv/MCXC.csv'),
    'ACT' : pd.read_csv('/home/rt2122/Data/original_catalogs/csv/ACT.csv')
}

# %%
det = det_cats['pz_rot28'].copy()
det = det[det['catalog'] == 'planck_z']
q = det['max_pred'].quantile(0.1) # 10% найденных скоплений из planck_z имеют max_pred <= q
q
# Out:
# 0.809162687510252

# %%
det = det_cats['pz_act_found2_22'].copy()
det = det[det['catalog'] == 'planck_z']
q = det['max_pred'].quantile(0.1) # 10% найденных скоплений из planck_z имеют max_pred <= q
q
# Out:
# 0.6397205097600818

# %%
det = det_cats['pz_all_found34'].copy()
det = det[det['catalog'] == 'planck_z']
q = det['max_pred'].quantile(0.1) # 10% найденных скоплений из planck_z имеют max_pred <= q
q
# Out:
# 0.6837768717668951

# %%
def m500_z_graph(cat_name, det_name, q_rat=0.1, big_pix=None, text=''):
    df = pd.read_csv(cat_name)
    df = df[df['status'] != 'fn']
    df.index = np.arange(len(df))
    
    true_cats = {'PSZ2(z)' : pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv'),
                'MCXC' : pd.read_csv('/home/rt2122/Data/clusters/mcxcwp.csv'),
                'ACT' : pd.read_csv('/home/rt2122/Data/clusters/actwp.csv')
                #'MCXC' : pd.read_csv('/home/rt2122/Data/original_catalogs/csv/MCXC.csv'),
                #'ACT' : pd.read_csv('/home/rt2122/Data/original_catalogs/csv/ACT.csv')
                }
    
    if not (big_pix is None):
        df = cut_cat(df, big_pix=big_pix)
        for tr_cat in true_cats:
            true_cats[tr_cat] = cut_cat(true_cats[tr_cat], big_pix=big_pix)
        
    true_sc = {key : SkyCoord(ra=np.array(true_cats[key]['RA']) * u.degree, 
                              dec=np.array(true_cats[key]['DEC']) * u.degree, frame='icrs') for key in true_cats}
    
    q = df[df['catalog'] == 'planck_z']['max_pred'].quantile(q_rat)
    sc = SkyCoord(ra=np.array(df['RA']) * u.degree, dec=np.array(df['DEC']) * u.degree, frame='icrs')
    
    for name in true_cats:
        idx, d2d, _ = true_sc[name].match_to_catalog_sky(sc)
        true_cats[name]['max_pred'] = 0
        true_cats[name]['max_pred'] = np.array(df['max_pred'][idx])
        matched = d2d.degree < (400 / 3600)
        true_cats[name]['matched'] = matched
    
    fig, ax = plt.subplots(1, 3, figsize=(30, 10), sharex=True, sharey=True)
    fig.tight_layout()
    for i, (st, en) in enumerate([[q, 1], [0.1, 1]]):
        for name, c in zip(true_cats, ['b', 'r', 'c']):
            cur_cat = true_cats[name]
            cur_cat = cur_cat[cur_cat['matched']]
            match_max_pred = np.logical_and(st <= cur_cat['max_pred'], cur_cat['max_pred'] <= en)
            s = ax[i].scatter(cur_cat[match_max_pred]['z'], cur_cat[match_max_pred]['M500'], c=c, alpha=0.2)
            s.set_label('{} max_pred > {:.2g}'.format(name, st))
            plt.yscale('log')
    
    for name, c in zip(true_cats, ['b', 'r', 'c']):
        cur_cat = true_cats[name]
        cur_cat = cur_cat[np.logical_not(cur_cat['matched'])]
        s = ax[2].scatter(cur_cat['z'], cur_cat['M500'], c=c, alpha=0.2)
        s.set_label('{} unmatched'.format(name))
        plt.yscale('log')
    
    ax[0].set_ylabel('M500')
    for i in range(3):
        ax[i].set_ylim(10**-1, 20)
        ax[i].set_xlabel('z')
        ax[i].grid(which='minor', axis='both', linestyle='--')
        ax[i].grid(which='major', axis='both', linestyle='--')
        ax[i].legend()
    ax[1].set_title(text)

# %%
m500_z_graph('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv', 'pz_all_found34', big_pix=west_val+east_val,
            text='4 pixels validatioon')

# %%
m500_z_graph('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv', 'pz_all_found34')

# %%
m500_z_graph('/home/rt2122/Data/detected_cats/full_pz_rot28_thr0.1_step8_no_fn.csv', 'pz_rot28')

# %%
m500_z_graph('/home/rt2122/Data/detected_cats/full_pz_rot28_thr0.1_step8_no_fn.csv', 'pz_rot28')

# %%
mcxc = pd.read_csv('/home/rt2122/Data/original_catalogs/csv/MCXC.csv')

# %%
planck_z = pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv')

# %%
pz_sc = SkyCoord(ra=np.array(planck_z['RA']) * u.degree, dec=np.array(planck_z['DEC']) * u.degree, frame='icrs')
mcxc_sc = SkyCoord(ra=np.array(mcxc['RA']) * u.degree, dec=np.array(mcxc['DEC']) * u.degree, frame='icrs')

# %%
idx, d2d, _ = pz_sc.match_to_catalog_sky(mcxc_sc)
planck_z['mcxc_M500'] = 0
planck_z['mcxc_M500'] = np.array(mcxc['M500'][idx])
matched = d2d.degree < (400 / 3600)
planck_z = planck_z[matched]
planck_z.index = np.arange(len(planck_z))

# %%
mcxc
# Out:
#            RA     DEC      z  M500
# 248    47.233  26.760  0.356  16.4
# 322    64.393 -11.908  0.443  22.1
# 1592  332.941  -3.828  0.397  18.1
# 1635  340.839  -9.595  0.447  17.4

# %%
mcxc = mcxc[np.logical_not(matched)]
mcxc.index = np.arange(len(mcxc))
mcxc[mcxc['M500'] > 14]
# Out:
# Empty DataFrame
# Columns: [RA, DEC, z, M500]
# Index: []

# %%
len(mcxc)
# Out:
# 529

# %%
len(pd.read_csv('/home/rt2122/Data/original_catalogs/csv/MCXC.csv'))
# Out:
# 1743

# %%
len(pd.read_csv('/home/rt2122/Data/clusters/mcxcwp.csv'))
# Out:
# 1193

# %%
mcxc
# Out:
#           RA     DEC       z    M500
# 0      0.488  12.073  0.2033  2.6927
# 1      0.799  -6.086  0.2320  5.2188
# 2      0.961   2.063  0.0924  1.7342
# 3      1.513 -34.724  0.1147  2.7122
# 4      1.591  10.868  0.1698  2.9941
# ..       ...     ...     ...     ...
# 543  357.711   6.161  0.0562  1.9360
# 544  357.919 -26.084  0.2264  7.8996
# 545  358.556 -10.413  0.0765  2.3160
# 546  358.909  11.343  0.0726  1.6934
# 547  359.260 -34.761  0.0475  2.6658
#
# [548 rows x 4 columns]

# %%
len(planck_z)
# Out:
# 1094

# %%
_, ax = plt.subplots(1, 1, figsize=(10, 10))
s = ax.scatter(planck_z[matched]['z'], planck_z[matched]['M500'], c='b', alpha=0.2, s=100)
s.set_label('planck_z')
s = ax.scatter(mcxc['z'], mcxc['M500'], c='r', alpha=0.2, s=100)
s.set_label('mcxc')
ax.set_xticks(np.arange(0, 1.5, 0.1))
ax.set_yticks(np.arange(0, 30, 5))
ax.legend()

# %%
planck_z
# Out:
#                    Name          RA        DEC       z      M500  \
# 0    PSZ2 G000.04+45.13  229.190512  -1.017222  0.1198  3.962411
# 1    PSZ2 G000.13+78.04  203.558683  20.255990  0.1710  5.122391
# 2    PSZ2 G000.40-41.86  316.084485 -41.354169  0.1651  5.297053
# 3    PSZ2 G000.77-35.69  307.972844 -40.598725  0.3416  6.333562
# 4    PSZ2 G002.77-56.16  334.659473 -38.879406  0.1411  4.411132
# ..                  ...         ...        ...     ...       ...
# 540  PSZ2 G357.75-41.77  315.929494 -43.325862  0.0487  1.546678
# 541  PSZ2 G358.21-87.49   10.519321 -28.533385  0.1082  3.647853
# 542  PSZ2 G358.94-70.57  352.780306 -36.549807  0.0957  2.523271
# 543  PSZ2 G358.98-67.26  348.926557 -37.779104  0.1786  5.224710
# 544  PSZ2 G359.07-32.12  303.018900 -41.486882  0.1496  4.721086
#
#              MCXC             RedMAPPer  mcxc_M500
# 0    J1516.5-0056  RMJ151653.9-010506.3     2.2053
# 1    J1334.1+2013  RMJ133408.7+201453.0     2.6730
# 2    J2104.3-4120                           4.1199
# 3    J2031.8-4037                           6.6240
# 4    J2218.6-3853                           3.9150
# ..            ...                   ...        ...
# 540  J2103.4-4319                           0.8373
# 541  J0042.1-2832                           3.5046
# 542  J2331.2-3630                           3.2815
# 543  J2315.7-3746                           4.5563
# 544  J2012.0-4129                           3.0302
#
# [545 rows x 8 columns]

# %%
m500_z_graph('/home/rt2122/Data/detected_cats/full_pz_rot28_thr0.1_step8_no_fn.csv', 'pz_rot28')

# %%
m500_z_graph('/home/rt2122/Data/detected_cats/full_pz_rot28_thr0.1_step8_no_fn.csv', 'pz_rot28')

# %%
all_found = pd.read_csv('/home/rt2122/Data/clusters/acts/all_found.csv')

# %%
set(all_found['catalog'])
# Out:
# {'actwp', 'mcxcwp', 'planck_no_z'}

# %%
df = pd.concat([
    pd.DataFrame({'planck_z' : len(pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv')),
                 'act' : 0, 'mcxc' : 0, 'planck_no_z' : 0, 'all' : len(pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv'))}, index=['pz_rot']),
    pd.DataFrame({'planck_z' : len(pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv')),
                 'act' : len(pd.read_csv('/home/rt2122/Data/clusters/acts/act_found_pz_rot_28.csv')),
                 'planck_no_z' : 0, 'mcxc' : 0,
                  'all' : len(pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv')) + 
                  len(pd.read_csv('/home/rt2122/Data/clusters/acts/act_found_pz_rot_28.csv'))
                 }, index=['pz_act_found2']),
    pd.DataFrame({'planck_z' : len(pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv')),
                  'act' : int(np.count_nonzero(all_found['catalog'] == 'actwp')),
                  'mcxc' : int(np.count_nonzero(all_found['catalog'] == 'mcxcwp')),
                  'planck_no_z' : int(np.count_nonzero(all_found['catalog'] == 'planck_no_z')),
                  'all' : len(pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv')) + len(all_found)
                 }, index=['pz_all_found'])
])

# %%
df[['planck_z', 'planck_no_z', 'mcxc', 'act', 'all']]
# Out:
#                planck_z  planck_no_z  mcxc  act   all
# pz_rot             1094            0     0    0  1094
# pz_act_found2      1094            0     0  536  1630
# pz_all_found       1094          454   219  576  2343

# %%
all_cl = pd.concat([pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv'), pd.read_csv('/home/rt2122/Data/clusters/mcxcwp.csv'), 
                               pd.read_csv('/home/rt2122/Data/clusters/actwp.csv')], ignore_index=True)

# %%
len(all_cl)
# Out:
# 6136

# %%
z_q = [all_cl['z'].quantile(i/6) for i in range(1, 6)]

# %%
all_cl0 = all_cl[all_cl['z'] < z_q[0]]

# %%
[all_cl0['M500'].quantile(i/6) for i in range(1, 6)]
# Out:
# [0.49284999999999984, 1.0462, 1.6326, 2.164433333333333, 2.921033333333334]

# %%
df = pd.DataFrame({'a' : [1, 2], 'b' : [5, 6]})
df
# Out:
#    a  b
# 0  1  5
# 1  2  6

# %%
df['matched'] = [True, False]

# %%
df
# Out:
#    a  b  matched
# 0  1  5     True
# 1  2  6    False

# %%
def m500_max_pred_graph(cat_name, det_name, q_rat=0.1):
    df = pd.read_csv(cat_name)
    df = df[df['status'] != 'fn']
    df.index = np.arange(len(df))
    
    true_cats = {'PSZ2(z)' : pd.read_csv('/home/rt2122/Data/clusters/planck_z.csv'),
                'MCXC' : pd.read_csv('/home/rt2122/Data/clusters/mcxcwp.csv'),
                'ACT' : pd.read_csv('/home/rt2122/Data/clusters/actwp.csv')
                #'MCXC' : pd.read_csv('/home/rt2122/Data/original_catalogs/csv/MCXC.csv'),
                #'ACT' : pd.read_csv('/home/rt2122/Data/original_catalogs/csv/ACT.csv')
                }
    true_sc = {key : SkyCoord(ra=np.array(true_cats[key]['RA']) * u.degree, 
                              dec=np.array(true_cats[key]['DEC']) * u.degree, frame='icrs') for key in true_cats}
    
    q = df[df['catalog'] == 'planck_z']['max_pred'].quantile(q_rat)
    sc = SkyCoord(ra=np.array(df['RA']) * u.degree, dec=np.array(df['DEC']) * u.degree, frame='icrs')
    
    for name in true_cats:
        idx, d2d, _ = true_sc[name].match_to_catalog_sky(sc)
        true_cats[name]['max_pred'] = 0
        true_cats[name]['max_pred'] = np.array(df['max_pred'][idx])
        matched = d2d.degree < (400 / 3600)
        true_cats[name]['matched'] = matched
    
    _, ax = plt.subplots(1, 3, figsize=(30, 10), sharex=True, sharey=True)
    for i, (st, en) in enumerate([[0.1, 1], [q, 1]]):
        for name, c in zip(true_cats, ['b', 'r', 'c']):
            cur_cat = true_cats[name]
            cur_cat = cur_cat[cur_cat['matched']]
            match_max_pred = np.logical_and(st <= cur_cat['max_pred'], cur_cat['max_pred'] <= en)
            s = ax[i].scatter(cur_cat[match_max_pred]['z'], cur_cat[match_max_pred]['M500'], c=c, alpha=0.2)
            s.set_label('{} max_pred > {:.2g}'.format(name, st))
            plt.yscale('log')
    
    for name, c in zip(true_cats, ['b', 'r', 'c']):
        cur_cat = true_cats[name]
        cur_cat = cur_cat[np.logical_not(cur_cat['matched'])]
        s = ax[2].scatter(cur_cat['z'], cur_cat['M500'], c=c, alpha=0.2)
        s.set_label('{} unmatched'.format(name))
        plt.yscale('log')
    
    for i in range(3):
        ax[i].set_ylim(10**-1, 20)
        ax[i].set_xlabel('z')
        ax[i].set_ylabel('M500')
        ax[i].grid(which='minor', axis='both', linestyle='--')
        ax[i].grid(which='major', axis='both', linestyle='--')
        ax[i].legend()

# %%
3600 * np.arange(0, 1500/3600, 35/3600)
# Out:
# array([   0.,   35.,   70.,  105.,  140.,  175.,  210.,  245.,  280.,
#         315.,  350.,  385.,  420.,  455.,  490.,  525.,  560.,  595.,
#         630.,  665.,  700.,  735.,  770.,  805.,  840.,  875.,  910.,
#         945.,  980., 1015., 1050., 1085., 1120., 1155., 1190., 1225.,
#        1260., 1295., 1330., 1365., 1400., 1435., 1470.])
