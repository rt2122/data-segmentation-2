# %%
import numpy as np
import pandas as pd
from DS_detector import rematch_cat
from DS_models_stat import make_histogram
from matplotlib import pyplot as plt

# %%
all_found = pd.read_csv('/home/rt2122/Data/clusters/acts/all_found.csv')

# %%
all_found
# Out:
#               RA        DEC      catalog
# 0     283.519410  26.482998  planck_no_z
# 1     281.194927  30.246774  planck_no_z
# 2     282.386761  22.454051  planck_no_z
# 3     279.339341  30.664193  planck_no_z
# 4     281.744111  16.843164  planck_no_z
# ...          ...        ...          ...
# 1244   68.395830 -29.100000        actwp
# 1245   90.768082 -38.265320        actwp
# 1246   75.713837 -31.013945        actwp
# 1247   82.167000 -32.858000       mcxcwp
# 1248   90.988200 -35.966531        actwp
#
# [1249 rows x 3 columns]

# %%
set(all_found['catalog'])
# Out:
# {'actwp', 'mcxcwp', 'planck_no_z'}

# %%
df = rematch_cat('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8_no_fn.csv', 
            clusters_dir='/home/rt2122/Data/original_catalogs/csv/')
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
_, ax = plt.subplots(1, 1, figsize=(10, 10))
make_histogram(ax, df['max_pred'][df['status'] == 'tp'], df['max_pred'][df['status'] == 'fp'], 20)

# %%
df = df[df['status'] == 'tp']
df.index = np.arange(len(df))

# %%
df
# Out:
#               RA        DEC  area   min_rad   max_rad  mean_rad  min_pred  \
# 0     260.797263  29.453179  25.0  1.665714  4.171203  2.931137  0.101302
# 1     259.249705  29.515445  39.0  2.311326  5.099633  3.633532  0.104650
# 2     258.585084  29.154516  37.0  1.899252  4.821417  3.509465  0.100698
# 3     260.853553  23.825607  27.0  1.721145  4.138158  2.971412  0.100674
# 4     259.267856  25.814784  32.0  2.152288  5.248476  3.271458  0.100586
# ...          ...        ...   ...       ...       ...       ...       ...
# 3498   68.400311 -29.105829  36.0  1.624118  5.034530  3.461675  0.105389
# 3499   85.694530 -35.987890  28.0  1.860392  4.038803  3.099976  0.105760
# 3500   75.661628 -31.040996  30.0  2.178750  4.388112  3.181670  0.110162
# 3501   82.157899 -32.869224  34.0  1.908243  4.804970  3.429946  0.111474
# 3502   90.961595 -35.972884  29.0  1.883518  4.251350  3.093123  0.103829
#
#       max_pred         tRA       tDEC status catalog      M500         z  \
# ...

# %%
#df = df[df['max_pred'] >= 0.8]
df.index=np.arange(len(df))
df
# Out:
#               RA        DEC  area   min_rad   max_rad  mean_rad  min_pred  \
# 0     260.797263  29.453179  25.0  1.665714  4.171203  2.931137  0.101302
# 1     259.249705  29.515445  39.0  2.311326  5.099633  3.633532  0.104650
# 2     258.585084  29.154516  37.0  1.899252  4.821417  3.509465  0.100698
# 3     260.853553  23.825607  27.0  1.721145  4.138158  2.971412  0.100674
# 4     259.267856  25.814784  32.0  2.152288  5.248476  3.271458  0.100586
# ...          ...        ...   ...       ...       ...       ...       ...
# 3498   68.400311 -29.105829  36.0  1.624118  5.034530  3.461675  0.105389
# 3499   85.694530 -35.987890  28.0  1.860392  4.038803  3.099976  0.105760
# 3500   75.661628 -31.040996  30.0  2.178750  4.388112  3.181670  0.110162
# 3501   82.157899 -32.869224  34.0  1.908243  4.804970  3.429946  0.111474
# 3502   90.961595 -35.972884  29.0  1.883518  4.251350  3.093123  0.103829
#
#       max_pred         tRA       tDEC status catalog      M500         z  \
# ...

# %%
df = df[['tRA', 'tDEC', 'catalog', 'max_pred']]

# %%
df.rename(columns={'tRA' : 'RA', 'tDEC' : 'DEC'}, inplace=True)
df
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#               RA        DEC catalog  max_pred
# 0     260.748958  29.460259      RM  0.429345
# 1     259.268213  29.584202      RM  0.684236
# 2     258.652932  29.150932      RM  0.644942
# 3     260.819800  23.754400   Abell  0.680946
# 4     259.202307  25.779575      RM  0.650705
# ...          ...        ...     ...       ...
# 3498   68.395830 -29.100000     ACT  0.370448
# 3499   85.732540 -35.997352     ACT  0.966874
# 3500   75.713837 -31.013945     ACT  0.620112
# 3501   82.167000 -32.858000    MCXC  0.487236
# 3502   90.988200 -35.966531     ACT  0.908625
#
# [3503 rows x 4 columns]

# %%
df.to_csv('/home/rt2122/Data/clusters/acts/found0.csv', index=False)
