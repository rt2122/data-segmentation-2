# %%
import numpy as np
import pandas as pd
from DS_Planck_Unet import gen_data_while_training
from DS_Planck_Unet import check_gen, val_pix
from tqdm.notebook import tqdm

# %%
val_gen = gen_data_while_training(val_pix, 20, '/home/rt2122/Data/Planck/coords/pz_act_jan_patches.csv',
        '/home/rt2122/Data/Planck/pregen_pics/', '/home/rt2122/Data/Planck/pregen_masks_act_jan/')

# %%
check_gen(val_gen)
# Out:
# (20, 64, 64, 6) (20, 64, 64, 1)

# %%
for i in tqdm(range(100000)):
    next(val_gen)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7673d68422b9> in <module>
#       1 for i in tqdm(range(100000)):
# ----> 2     next(val_gen)
#
# ~/L/git/data-segmentation-2/modules/DS_Planck_Unet.py in gen_data_while_training(big_pixels, batch_size, patches_file, pregen_pics, pregen_masks, size, no_sample, rotate_aug)
#     391
#     392
# --> 393             yield np.stack(pics), np.stack(masks)
#
# <__array_function__ internals> in stack(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/shape_base.py in stack(arrays, axis, out)
#     431     sl = (slice(None),) * axis + (_nx.newaxis,)
#     432     expanded_arrays = [arr[sl] for arr in arrays]
# --> 433     return _nx.concatenate(expanded_arrays, axis=axis, out=out)
#     434
#     435
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
