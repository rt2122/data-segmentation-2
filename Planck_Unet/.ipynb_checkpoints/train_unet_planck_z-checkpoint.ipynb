# %%
from DS_Planck_Unet import *
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model = unet_planck()

# %%
batch_size = 20
min_rad = 0.08

# %%
val_gen = gen_data('/home/rt2122/Data/clusters/planck_z.csv', val_pix, 4, 
                   search_nside=256, min_rad=min_rad)
train_gen = gen_data('/home/rt2122/Data/clusters/planck_z.csv', train_pix, batch_size, 
                    search_nside=256, min_rad=min_rad)
test_gen = gen_data('/home/rt2122/Data/clusters/planck_z.csv', test_pix, 1, 
                   search_nside=256, min_rad=min_rad)

# %%
check_gen(test_gen)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
filepath='/home/rt2122/Models/planck_z/model.ep{epoch:04d}-vl{val_loss:.6f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)
callbacks_list = [checkpoint]

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=10, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=0)
# Out:
# WARNING:tensorflow:From <ipython-input-7-151159b4966c>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 20/20 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9659 - iou: 0.0020 - dice: 0.0040
# Epoch 00001: val_loss improved from inf to 0.09878, saving model to /home/rt2122/Models/planck_z/model.ep01-vl0.10.h5
# 20/20 [==============================] - 219s 11s/step - loss: 0.1519 - accuracy: 0.9659 - iou: 0.0020 - dice: 0.0040 - val_loss: 0.0988 - val_accuracy: 0.9963 - val_iou: 7.7909e-04 - val_dice: 0.0026
# Epoch 2/10
# 20/20 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9957 - iou: 0.0073 - dice: 0.0146
# Epoch 00002: val_loss did not improve from 0.09878
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=50, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=10)
# Out:
# Epoch 11/50
# 20/20 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9956 - iou: 0.0193 - dice: 0.0387
# Epoch 00011: val_loss did not improve from 0.04581
# 20/20 [==============================] - 230s 11s/step - loss: 0.0293 - accuracy: 0.9956 - iou: 0.0193 - dice: 0.0387 - val_loss: 0.1388 - val_accuracy: 0.9962 - val_iou: 0.0032 - val_dice: 0.0065
# Epoch 12/50
# 20/20 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9955 - iou: 0.0258 - dice: 0.0517
# Epoch 00012: val_loss did not improve from 0.04581
# 20/20 [==============================] - 229s 11s/step - loss: 0.0282 - accuracy: 0.9955 - iou: 0.0258 - dice: 0.0517 - val_loss: 0.1032 - val_accuracy: 0.9962 - val_iou: 0.0039 - val_dice: 0.0079
# Epoch 13/50
# 20/20 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9955 - iou: 0.0221 - dice: 0.0443
# Epoch 00013: val_loss did not improve from 0.04581
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=100, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=50)
# Out:
# Epoch 51/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9958 - iou: 0.0490 - dice: 0.0982
# Epoch 00051: val_loss did not improve from 0.04581
# 20/20 [==============================] - 238s 12s/step - loss: 0.0189 - accuracy: 0.9958 - iou: 0.0490 - dice: 0.0982 - val_loss: 0.0840 - val_accuracy: 0.9965 - val_iou: 0.0083 - val_dice: 0.0166
# Epoch 52/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9960 - iou: 0.0565 - dice: 0.1132
# Epoch 00052: val_loss did not improve from 0.04581
# 20/20 [==============================] - 222s 11s/step - loss: 0.0176 - accuracy: 0.9960 - iou: 0.0565 - dice: 0.1132 - val_loss: 0.1237 - val_accuracy: 0.9963 - val_iou: 0.0067 - val_dice: 0.0134
# Epoch 53/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9959 - iou: 0.0459 - dice: 0.0919
# Epoch 00053: val_loss did not improve from 0.04581
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=150, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=100)
# Out:
# Epoch 101/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9977 - iou: 0.4259 - dice: 0.8518
# Epoch 00101: val_loss did not improve from 0.01690
# 20/20 [==============================] - 238s 12s/step - loss: 0.0056 - accuracy: 0.9977 - iou: 0.4259 - dice: 0.8518 - val_loss: 0.0213 - val_accuracy: 0.9945 - val_iou: 0.0639 - val_dice: 0.1283
# Epoch 102/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9978 - iou: 0.4458 - dice: 0.8917
# Epoch 00102: val_loss did not improve from 0.01690
# 20/20 [==============================] - 232s 12s/step - loss: 0.0055 - accuracy: 0.9978 - iou: 0.4458 - dice: 0.8917 - val_loss: 0.0237 - val_accuracy: 0.9930 - val_iou: 0.0674 - val_dice: 0.1352
# Epoch 103/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9980 - iou: 0.4678 - dice: 0.9357
# Epoch 00103: val_loss did not improve from 0.01690
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=200, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=150)
# Out:
# Epoch 151/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992 - iou: 0.7379 - dice: 1.4756
# Epoch 00151: val_loss did not improve from 0.01132
# 20/20 [==============================] - 247s 12s/step - loss: 0.0020 - accuracy: 0.9992 - iou: 0.7379 - dice: 1.4756 - val_loss: 0.0160 - val_accuracy: 0.9957 - val_iou: 0.1762 - val_dice: 0.3529
# Epoch 152/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9993 - iou: 0.7669 - dice: 1.5336
# Epoch 00152: val_loss did not improve from 0.01132
# 20/20 [==============================] - 237s 12s/step - loss: 0.0018 - accuracy: 0.9993 - iou: 0.7669 - dice: 1.5336 - val_loss: 0.0200 - val_accuracy: 0.9958 - val_iou: 0.0758 - val_dice: 0.1527
# Epoch 153/200
# 20/20 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994 - iou: 0.7921 - dice: 1.5841
# Epoch 00153: val_loss did not improve from 0.01132
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=250, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=200)
# Out:
# Epoch 201/250
# 20/20 [==============================] - ETA: 0s - loss: 5.8012e-04 - accuracy: 0.9998 - iou: 0.9154 - dice: 1.8306
# Epoch 00201: val_loss did not improve from 0.01132
# 20/20 [==============================] - 321s 16s/step - loss: 5.8012e-04 - accuracy: 0.9998 - iou: 0.9154 - dice: 1.8306 - val_loss: 0.0570 - val_accuracy: 0.9962 - val_iou: 9.3381e-05 - val_dice: 0.0017
# Epoch 202/250
# 20/20 [==============================] - ETA: 0s - loss: 6.1212e-04 - accuracy: 0.9998 - iou: 0.9140 - dice: 1.8278
# Epoch 00202: val_loss did not improve from 0.01132
# 20/20 [==============================] - 354s 18s/step - loss: 6.1212e-04 - accuracy: 0.9998 - iou: 0.9140 - dice: 1.8278 - val_loss: 0.0314 - val_accuracy: 0.9961 - val_iou: 0.0896 - val_dice: 0.1803
# Epoch 203/250
# 20/20 [==============================] - ETA: 0s - loss: 5.1420e-04 - accuracy: 0.9998 - iou: 0.9272 - dice: 1.8542
# Epoch 00203: val_loss did not improve from 0.01132
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.fit_generator(generator=train_gen, steps_per_epoch=20, epochs=300, 
                    validation_data=val_gen, validation_steps=1, 
                    callbacks=callbacks_list, initial_epoch=250)
# Out:
# Epoch 251/300
# 20/20 [==============================] - ETA: 0s - loss: 2.0817e-04 - accuracy: 0.9999 - iou: 0.9675 - dice: 1.9348
# Epoch 00251: val_loss did not improve from 0.01132
# 20/20 [==============================] - 238s 12s/step - loss: 2.0817e-04 - accuracy: 0.9999 - iou: 0.9675 - dice: 1.9348 - val_loss: 0.0439 - val_accuracy: 0.9952 - val_iou: 0.0091 - val_dice: 0.0195
# Epoch 252/300
# 20/20 [==============================] - ETA: 0s - loss: 2.7104e-04 - accuracy: 0.9999 - iou: 0.9614 - dice: 1.9225
# Epoch 00252: val_loss did not improve from 0.01132
# 20/20 [==============================] - 228s 11s/step - loss: 2.7104e-04 - accuracy: 0.9999 - iou: 0.9614 - dice: 1.9225 - val_loss: 0.0412 - val_accuracy: 0.9958 - val_iou: 0.0107 - val_dice: 0.0227
# Epoch 253/300
# 20/20 [==============================] - ETA: 0s - loss: 3.8196e-04 - accuracy: 0.9999 - iou: 0.9520 - dice: 1.9038
# Epoch 00253: val_loss did not improve from 0.01132
# ...

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)
