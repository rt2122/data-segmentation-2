# %%
from DS_Planck_Unet import *
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint
import pickle
from tensorflow import convert_to_tensor

# %%
model = unet_planck()

# %%
batch_size = 20
min_rad = 2

# %%
train_gen = gen_data_from_pregen('/home/rt2122/Data/Planck/train/', batch_size)
val_gen = gen_data_from_pregen('/home/rt2122/Data/Planck/val/', batch_size)
test_gen = gen_data_from_pregen('/home/rt2122/Data/Planck/test/', 1)

# %%
check_gen(test_gen)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
filepath='/home/rt2122/Models/planck_z/f8d2.ep{epoch:04d}-vl{val_loss:.6f}-l{loss:.6f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, 
                            save_best_only=True, mode='min', save_weights_only=False)
callbacks_list = [checkpoint]

# %%
history = model.fit_generator(generator=train_gen, steps_per_epoch=4800, epochs=10, 
                    validation_data=val_gen, validation_steps=40, 
                    callbacks=callbacks_list, initial_epoch=0)
# Out:
# WARNING:tensorflow:From <ipython-input-8-10edb3aeb95e>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9912 - iou: 0.0139 - dice: 0.0280
# Epoch 00001: val_loss improved from inf to 0.02443, saving model to /home/rt2122/Models/planck_z/f8d2.ep0001-vl0.024432-l0.121729.hdf5
# 4800/4800 [==============================] - 3181s 663ms/step - loss: 0.1217 - accuracy: 0.9912 - iou: 0.0139 - dice: 0.0280 - val_loss: 0.0244 - val_accuracy: 0.9960 - val_iou: 0.0425 - val_dice: 0.0852
# Epoch 2/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9962 - iou: 0.0673 - dice: 0.1347
# Epoch 00002: val_loss improved from 0.02443 to 0.01358, saving model to /home/rt2122/Models/planck_z/f8d2.ep0002-vl0.013581-l0.017607.hdf5
# 4800/4800 [==============================] - 3263s 680ms/step - loss: 0.0176 - accuracy: 0.9962 - iou: 0.0673 - dice: 0.1347 - val_loss: 0.0136 - val_accuracy: 0.9960 - val_iou: 0.1233 - val_dice: 0.2469
# Epoch 3/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9962 - iou: 0.1457 - dice: 0.2915
# Epoch 00003: val_loss improved from 0.01358 to 0.00965, saving model to /home/rt2122/Models/planck_z/f8d2.ep0003-vl0.009654-l0.010940.hdf5
# 4800/4800 [==============================] - 3033s 632ms/step - loss: 0.0109 - accuracy: 0.9962 - iou: 0.1457 - dice: 0.2915 - val_loss: 0.0097 - val_accuracy: 0.9960 - val_iou: 0.1879 - val_dice: 0.3759
# Epoch 4/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9967 - iou: 0.2335 - dice: 0.4671
# Epoch 00004: val_loss improved from 0.00965 to 0.00840, saving model to /home/rt2122/Models/planck_z/f8d2.ep0004-vl0.008401-l0.008484.hdf5
# 4800/4800 [==============================] - 2580s 538ms/step - loss: 0.0085 - accuracy: 0.9967 - iou: 0.2335 - dice: 0.4671 - val_loss: 0.0084 - val_accuracy: 0.9972 - val_iou: 0.2703 - val_dice: 0.5407
# Epoch 5/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9975 - iou: 0.3303 - dice: 0.6607
# Epoch 00005: val_loss improved from 0.00840 to 0.00762, saving model to /home/rt2122/Models/planck_z/f8d2.ep0005-vl0.007622-l0.006918.hdf5
# 4800/4800 [==============================] - 2721s 567ms/step - loss: 0.0069 - accuracy: 0.9975 - iou: 0.3303 - dice: 0.6607 - val_loss: 0.0076 - val_accuracy: 0.9974 - val_iou: 0.2961 - val_dice: 0.5923
# Epoch 6/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9977 - iou: 0.3742 - dice: 0.7485
# Epoch 00006: val_loss did not improve from 0.00762
# 4800/4800 [==============================] - 2571s 536ms/step - loss: 0.0061 - accuracy: 0.9977 - iou: 0.3742 - dice: 0.7485 - val_loss: 0.0077 - val_accuracy: 0.9974 - val_iou: 0.3162 - val_dice: 0.6325
# Epoch 7/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9978 - iou: 0.4071 - dice: 0.8142
# Epoch 00007: val_loss improved from 0.00762 to 0.00693, saving model to /home/rt2122/Models/planck_z/f8d2.ep0007-vl0.006934-l0.005567.hdf5
# 4800/4800 [==============================] - 2957s 616ms/step - loss: 0.0056 - accuracy: 0.9978 - iou: 0.4071 - dice: 0.8142 - val_loss: 0.0069 - val_accuracy: 0.9975 - val_iou: 0.3474 - val_dice: 0.6949
# Epoch 8/10
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9979 - iou: 0.4295 - dice: 0.8591
# Epoch 00008: val_loss did not improve from 0.00693
# 4800/4800 [==============================] - 2554s 532ms/step - loss: 0.0052 - accuracy: 0.9979 - iou: 0.4295 - dice: 0.8591 - val_loss: 0.0071 - val_accuracy: 0.9974 - val_iou: 0.3521 - val_dice: 0.7043
# Epoch 9/10
#  214/4800 [>.............................] - ETA: 49:53 - loss: 0.0050 - accuracy: 0.9980 - iou: 0.4444 - dice: 0.8887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-10edb3aeb95e> in <module>
# ----> 1 history = model.fit_generator(generator=train_gen, steps_per_epoch=4800, epochs=10,
#       2                     validation_data=val_gen, validation_steps=40,
#       3                     callbacks=callbacks_list, initial_epoch=0)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1463     """
#    1464     _keras_api_gauge.get_cell('fit_generator').set(True)
# -> 1465     return self.fit(
#    1466         generator,
#    1467         steps_per_epoch=steps_per_epoch,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model = load_planck_model(
    '/home/rt2122/Models/planck_z/f8d2.ep0007-vl0.006934-l0.005567.hdf5')

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
history = model.fit_generator(generator=train_gen, steps_per_epoch=4800, epochs=20, 
                    validation_data=val_gen, validation_steps=40, 
                    callbacks=callbacks_list, initial_epoch=7)
# Out:
# WARNING:tensorflow:From <ipython-input-8-5fde3ef6aed1>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 8/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9979 - iou: 0.4308 - dice: 0.8617
# Epoch 00008: val_loss improved from inf to 0.00676, saving model to /home/rt2122/Models/planck_z/f8d2.ep0008-vl0.006764-l0.005214.hdf5
# 4800/4800 [==============================] - 2482s 517ms/step - loss: 0.0052 - accuracy: 0.9979 - iou: 0.4308 - dice: 0.8617 - val_loss: 0.0068 - val_accuracy: 0.9975 - val_iou: 0.3597 - val_dice: 0.7194
# Epoch 9/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9980 - iou: 0.4512 - dice: 0.9025
# Epoch 00009: val_loss did not improve from 0.00676
# 4800/4800 [==============================] - 2022s 421ms/step - loss: 0.0049 - accuracy: 0.9980 - iou: 0.4512 - dice: 0.9025 - val_loss: 0.0069 - val_accuracy: 0.9976 - val_iou: 0.3612 - val_dice: 0.7224
# Epoch 10/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9981 - iou: 0.4670 - dice: 0.9340
# Epoch 00010: val_loss improved from 0.00676 to 0.00662, saving model to /home/rt2122/Models/planck_z/f8d2.ep0010-vl0.006621-l0.004716.hdf5
# 4800/4800 [==============================] - 1973s 411ms/step - loss: 0.0047 - accuracy: 0.9981 - iou: 0.4670 - dice: 0.9340 - val_loss: 0.0066 - val_accuracy: 0.9976 - val_iou: 0.3565 - val_dice: 0.7131
# Epoch 11/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9982 - iou: 0.4822 - dice: 0.9644
# Epoch 00011: val_loss did not improve from 0.00662
# 4800/4800 [==============================] - 2035s 424ms/step - loss: 0.0045 - accuracy: 0.9982 - iou: 0.4822 - dice: 0.9644 - val_loss: 0.0068 - val_accuracy: 0.9976 - val_iou: 0.3832 - val_dice: 0.7665
# Epoch 12/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9982 - iou: 0.4950 - dice: 0.9900
# Epoch 00012: val_loss did not improve from 0.00662
# 4800/4800 [==============================] - 1970s 410ms/step - loss: 0.0044 - accuracy: 0.9982 - iou: 0.4950 - dice: 0.9900 - val_loss: 0.0068 - val_accuracy: 0.9975 - val_iou: 0.3830 - val_dice: 0.7661
# Epoch 13/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9983 - iou: 0.5069 - dice: 1.0138
# Epoch 00013: val_loss did not improve from 0.00662
# 4800/4800 [==============================] - 2049s 427ms/step - loss: 0.0042 - accuracy: 0.9983 - iou: 0.5069 - dice: 1.0138 - val_loss: 0.0068 - val_accuracy: 0.9976 - val_iou: 0.3933 - val_dice: 0.7866
# Epoch 14/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9983 - iou: 0.5185 - dice: 1.0369
# Epoch 00014: val_loss improved from 0.00662 to 0.00657, saving model to /home/rt2122/Models/planck_z/f8d2.ep0014-vl0.006570-l0.004067.hdf5
# 4800/4800 [==============================] - 2019s 421ms/step - loss: 0.0041 - accuracy: 0.9983 - iou: 0.5185 - dice: 1.0369 - val_loss: 0.0066 - val_accuracy: 0.9977 - val_iou: 0.3977 - val_dice: 0.7954
# Epoch 15/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9984 - iou: 0.5265 - dice: 1.0529
# Epoch 00015: val_loss improved from 0.00657 to 0.00613, saving model to /home/rt2122/Models/planck_z/f8d2.ep0015-vl0.006127-l0.003979.hdf5
# 4800/4800 [==============================] - 1982s 413ms/step - loss: 0.0040 - accuracy: 0.9984 - iou: 0.5265 - dice: 1.0529 - val_loss: 0.0061 - val_accuracy: 0.9977 - val_iou: 0.3978 - val_dice: 0.7956
# Epoch 16/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9984 - iou: 0.5383 - dice: 1.0765
# Epoch 00016: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 2024s 422ms/step - loss: 0.0038 - accuracy: 0.9984 - iou: 0.5383 - dice: 1.0765 - val_loss: 0.0063 - val_accuracy: 0.9977 - val_iou: 0.4137 - val_dice: 0.8275
# Epoch 17/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - iou: 0.5465 - dice: 1.0930
# Epoch 00017: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 1974s 411ms/step - loss: 0.0037 - accuracy: 0.9985 - iou: 0.5465 - dice: 1.0930 - val_loss: 0.0064 - val_accuracy: 0.9976 - val_iou: 0.4056 - val_dice: 0.8113
# Epoch 18/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9985 - iou: 0.5544 - dice: 1.1087
# Epoch 00018: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 2044s 426ms/step - loss: 0.0037 - accuracy: 0.9985 - iou: 0.5544 - dice: 1.1087 - val_loss: 0.0063 - val_accuracy: 0.9977 - val_iou: 0.4229 - val_dice: 0.8458
# Epoch 19/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9985 - iou: 0.5619 - dice: 1.1237
# Epoch 00019: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 1977s 412ms/step - loss: 0.0036 - accuracy: 0.9985 - iou: 0.5619 - dice: 1.1237 - val_loss: 0.0063 - val_accuracy: 0.9977 - val_iou: 0.4273 - val_dice: 0.8547
# Epoch 20/20
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9986 - iou: 0.5690 - dice: 1.1379
# Epoch 00020: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 2040s 425ms/step - loss: 0.0035 - accuracy: 0.9986 - iou: 0.5690 - dice: 1.1379 - val_loss: 0.0067 - val_accuracy: 0.9975 - val_iou: 0.4098 - val_dice: 0.8195

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
with open('/home/rt2122/Models/f8d2.ep7-20.history', 'wb') as f:
    pickle.dump(history.history, f)

# %%
history = model.fit_generator(generator=train_gen, steps_per_epoch=4800, epochs=31, 
                    validation_data=val_gen, validation_steps=40, 
                    callbacks=callbacks_list, initial_epoch=20)
# Out:
# Epoch 21/31
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - iou: 0.5766 - dice: 1.1532
# Epoch 00021: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 2768s 577ms/step - loss: 0.0034 - accuracy: 0.9986 - iou: 0.5766 - dice: 1.1532 - val_loss: 0.0067 - val_accuracy: 0.9976 - val_iou: 0.4172 - val_dice: 0.8344
# Epoch 22/31
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - iou: 0.5821 - dice: 1.1641
# Epoch 00022: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 2533s 528ms/step - loss: 0.0034 - accuracy: 0.9986 - iou: 0.5821 - dice: 1.1641 - val_loss: 0.0061 - val_accuracy: 0.9977 - val_iou: 0.4334 - val_dice: 0.8667
# Epoch 23/31
# 4800/4800 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - iou: 0.5883 - dice: 1.1765
# Epoch 00023: val_loss did not improve from 0.00613
# 4800/4800 [==============================] - 2451s 511ms/step - loss: 0.0033 - accuracy: 0.9986 - iou: 0.5883 - dice: 1.1765 - val_loss: 0.0065 - val_accuracy: 0.9977 - val_iou: 0.4316 - val_dice: 0.8632
# Epoch 24/31
#  290/4800 [>.............................] - ETA: 40:29 - loss: 0.0033 - accuracy: 0.9986 - iou: 0.5906 - dice: 1.1811
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-95340dea0877> in <module>
# ----> 1 history = model.fit_generator(generator=train_gen, steps_per_epoch=4800, epochs=31,
#       2                     validation_data=val_gen, validation_steps=40,
#       3                     callbacks=callbacks_list, initial_epoch=20)
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1463     """
#    1464     _keras_api_gauge.get_cell('fit_generator').set(True)
# -> 1465     return self.fit(
#    1466         generator,
#    1467         steps_per_epoch=steps_per_epoch,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
check_gen(test_gen, model)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
model.save('/home/rt2122/Models/planck_z/f8d2.ep0023.hdf5')

# %%
with open('/home/rt2122/Models/f8d2.ep21-23.history', 'wb') as f:
    pickle.dump(history.history, f)
