# %%
import numpy as np
import pandas as pd
from DS_Planck_Unet import *
from DS_detector import *

# %%
model = load_planck_model(
    '/home/rt2122/Models/planck_z/f8d2.ep0014-vl0.006570-l0.004067.hdf5')

# %%
all_dict = gen_pics_for_detection(6, model)

# %%
coords = detect_clusters(all_dict, 0.4)
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
coords.shape
# Out:
# (122, 9)

# %%
coords[coords['status'] == 'fp']
# Out:
#             RA        DEC  area   min_rad   max_rad  min_pred  max_pred  \
# 1   161.467197  78.126561  11.0  0.626627  2.561446  0.401674  0.685706
# 2   162.696027  76.059708   1.0  0.000000  1.414214  0.436257  0.436257
# 7   186.032750  74.209693  10.0  1.334084  2.889388  0.404894  0.704375
# 8   187.943700  74.675908   8.0  0.870983  2.423663  0.409574  0.604940
# 12  242.729493  80.477600   3.0  0.447208  1.829483  0.463462  0.578811
# 13  204.733158  78.183256  13.0  0.700204  2.980943  0.428422  0.781113
# 14  257.194247  78.548227  19.0  1.985090  3.898565  0.415812  0.938106
# 17  205.209488  75.701507   3.0  0.448282  1.819220  0.408980  0.480205
# 30  243.161100  71.524720  11.0  0.963092  2.490142  0.434382  0.824713
# 32  216.198500  66.392099   4.0  0.734834  2.121384  0.428976  0.500726
# 34  207.981014  61.070843  11.0  0.885640  2.992563  0.402437  0.868999
# 36  251.077157  67.944603  10.0  0.572649  2.527094  0.470798  0.803837
# ...

# %%
coords[coords['status'] == 'tp']
# Out:
#             RA        DEC  area   min_rad   max_rad  min_pred  max_pred  \
# 0   171.522433  83.983315   7.0  0.689688  2.490028  0.500296  0.885333
# 3   261.411216  85.879280  19.0  1.478872  3.613255  0.508190  0.998537
# 4   173.409443  75.115466   3.0  0.468852  1.882454  0.414668  0.466701
# 5   171.923132  71.105538  19.0  1.134615  3.556877  0.430976  0.922336
# 6   178.983605  73.566323  15.0  1.070389  3.143234  0.403708  0.760757
# 9   181.797649  71.686960  14.0  0.921796  3.343648  0.482473  0.813310
# 10  284.353067  74.919484  11.0  1.081440  3.332216  0.425504  0.868978
# 11  275.878223  78.388854  17.0  0.978495  3.508872  0.434119  0.984679
# 15  245.108283  79.184374   1.0  0.000000  1.414214  0.450607  0.450607
# 16  208.761411  77.263916  17.0  1.015839  3.472759  0.465352  0.990765
# 18  198.198805  72.885503  15.0  0.803303  3.251297  0.402105  0.802152
# 19  199.059625  72.553462   6.0  0.275900  2.328029  0.406776  0.664781
# ...

# %%
coords[coords['status'] == 'fn'][coords['catalog'] == 'planck_z']
# Out:
# <ipython-input-9-f19fd7addfbe>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   coords[coords['status'] == 'fn'][coords['catalog'] == 'planck_z']
#              RA        DEC  area  min_rad  max_rad  min_pred  max_pred status  \
# 111  246.903435  65.396317   NaN      NaN      NaN       NaN       NaN     fn
# 112  248.977644  66.202314   NaN      NaN      NaN       NaN       NaN     fn
# 113  231.052549  62.022709   NaN      NaN      NaN       NaN       NaN     fn
# 114  238.037819  65.340540   NaN      NaN      NaN       NaN       NaN     fn
# 115  236.709588  69.944118   NaN      NaN      NaN       NaN       NaN     fn
# 116  216.777337  65.652811   NaN      NaN      NaN       NaN       NaN     fn
# 117  256.100465  78.632469   NaN      NaN      NaN       NaN       NaN     fn
# 118  213.306316  74.292047   NaN      NaN      NaN       NaN       NaN     fn
# 119  238.760353  84.163702   NaN      NaN      NaN       NaN       NaN     fn
# ...

# %%
stat = detect_clusters(all_dict, 0.4, ret_coords=False)
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
stat['planck_z']
# Out:
#    tp  fp  tn  fn
# 0  29   0  58  11

# %%
stat['planck_no_z']
# Out:
#    tp  fp  tn  fn
# 0   9   0  58   9

# %%
stat['mcxcwp']
# Out:
#    tp  fp  tn  fn
# 0   2   0  58  48

# %%
all_dict = gen_pics_for_detection(6, model, step=16)

# %%
stat = detect_clusters(all_dict, 0.2, ret_coords=False, match_before_merge=True)
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
stat
# Out:
#    tp   fp   tn  fn      catalog
# 0  16  120  746   2  planck_no_z
# 1  39  120  746   1     planck_z
# 2   7  120  746  43       mcxcwp

# %%
stat
# Out:
#    tp  fp    tn  fn      catalog
# 0  23   3  1321  17     planck_z
# 1   0   3  1321  50       mcxcwp
# 2   3   3  1321  15  planck_no_z

# %%
a = pd.DataFrame({'RA' : [1, 2, 1, None, None], 
                  'DEC':[2, 2, 2, None, None], 
                  'idx' : [5, 6, 7, 8, 9]})
a
# Out:
#     RA  DEC  idx
# 0  1.0  2.0    5
# 1  2.0  2.0    6
# 2  1.0  2.0    7
# 3  NaN  NaN    8
# 4  NaN  NaN    9

# %%
a = a.drop_duplicates(subset=['RA', 'DEC'])

# %%
a
# Out:
#     RA  DEC  idx
# 0  1.0  2.0    5
# 1  2.0  2.0    6
# 3  NaN  NaN    8
