# %%
import numpy as np
from matplotlib import pyplot as plt
import pickle
import pandas as pd
from DS_data_transformation import draw_df

# %%
h = None
with open('/home/rt2122/Models/f8d2.ep7-20.history', 'rb') as f:
    h = pd.DataFrame(pickle.load(f))

# %%
h
# Out:
#         loss  accuracy       iou      dice  val_loss  val_accuracy   val_iou  \
# 0   0.005214  0.997940  0.430845  0.861722  0.006764      0.997498  0.359689
# 1   0.004930  0.998035  0.451228  0.902479  0.006910      0.997610  0.361161
# 2   0.004716  0.998110  0.467007  0.934028  0.006621      0.997577  0.356525
# 3   0.004517  0.998181  0.482177  0.964363  0.006839      0.997610  0.383237
# 4   0.004350  0.998239  0.495017  0.990037  0.006787      0.997540  0.383009
# 5   0.004211  0.998293  0.506892  1.013781  0.006773      0.997633  0.393269
# 6   0.004067  0.998342  0.518459  1.036910  0.006570      0.997659  0.397697
# 7   0.003979  0.998381  0.526470  1.052928  0.006127      0.997668  0.397800
# 8   0.003839  0.998427  0.538268  1.076518  0.006294      0.997670  0.413708
# 9   0.003747  0.998466  0.546521  1.093019  0.006428      0.997648  0.405622
# 10  0.003660  0.998495  0.554380  1.108734  0.006329      0.997703  0.422880
# ...

# %%
draw_df({'loss':h['loss'],
        'val_loss':h['val_loss']}, base=h.index, invert=False)

# %%
draw_df({'iou':h['iou'],
        'dice':h['dice'],
        'acc':h['accuracy']}, base=h.index, invert=False)
