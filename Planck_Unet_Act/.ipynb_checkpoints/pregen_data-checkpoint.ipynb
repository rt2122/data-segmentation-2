# %%
import numpy as np
import os
import pandas as pd
from tqdm.notebook import tqdm
from DS_Planck_Unet import *
from DS_healpix_fragmentation import one_pixel_fragmentation, matr2dict, radec2pix
from matplotlib import pyplot as plt

# %%
clusters = ['/home/rt2122/Data/clusters/planck_z.csv', 
            '/home/rt2122/Data/clusters/act.csv']

# %%
for i in tqdm(range(48)):
    
    matr = one_pixel_fragmentation(2, i, 10)
    _, cl_df = pixels_with_clusters(clusters, i, 256, 
                                 min_rad = 2.0)
    pic, mask = draw_pic_with_mask(None, 
                        clusters_arr=np.stack([cl_df['RA'], cl_df['DEC']]).T, 
                        matr=matr)
    cur_dir = os.path.join('/home/rt2122/Data/Planck/pregen_act/', str(i))
    os.mkdir(cur_dir)
    np.save(os.path.join(cur_dir, 'pic'), pic)
    np.save(os.path.join(cur_dir, 'mask'), mask)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=48.0), HTML(value='')))

# %%
90000/4
# Out:
# 22500.0

# %%
def gen_data_in_one_pix(ipix, n_patches, clusters_files, idx, size=64, 
                        outpath='/home/rt2122/Data/Planck/train_act/', 
                        inpath='/home/rt2122/Data/Planck/pregen_act/'):
    matr = one_pixel_fragmentation(2, ipix, 10)
    mdict = matr2dict(matr) 
    all_pixels = set()

    df = [pd.read_csv(clusters_file) for clusters_file in clusters_files]
    df = pd.concat(df, ignore_index=True)

    cl_pix = radec2pix(df['RA'], df['DEC'], nside=2048)
    cl_pix = [mdict[pix] for pix in cl_pix if pix in mdict]
    for pix in cl_pix:
        x_cl, y_cl = pix
        all_pixels = all_pixels.union(set(
            [(x, y) for x in range(max(x_cl-size+1, 64), min(x_cl+1,matr.shape[0]-size)) 
                for y in range(max(y_cl-size+1, 64), min(y_cl+1,matr.shape[1]-size))]))
    rand_idx = None
    if n_patches >= len(all_pixels):
        rand_idx = np.arange(len(all_pixels))
    else:
        rand_idx = np.random.choice(np.arange(len(all_pixels)), n_patches, 
                                    replace=False)
    lu_corners = np.array(list(all_pixels))[rand_idx.astype(int)]
    pic = np.load(os.path.join(inpath, str(ipix), 'pic.npy'))
    mask = np.load(os.path.join(inpath, str(ipix), 'mask.npy'))
    
    if not os.path.isdir(os.path.join(outpath, 'x')):
        os.mkdir(os.path.join(outpath, 'x'))
    if not os.path.isdir(os.path.join(outpath, 'y')):
        os.mkdir(os.path.join(outpath, 'y'))
    
    for x, y in lu_corners:
        c_pic = pic[x:x+size,y:y+size,:]
        c_mask = mask[x:x+size,y:y+size,:]
        
        np.save(os.path.join(outpath, 'x', str(idx)), c_pic)
        np.save(os.path.join(outpath, 'y', str(idx)), c_mask)
        
        idx += 1
    return idx

# %%
gen_data_in_one_pix(0, 10, clusters,
                   outpath='/home/rt2122/Data/Planck/check_gen/', idx=0)
# Out:
# 10

# %%
pic = np.load('/home/rt2122/Data/Planck/check_gen/x/6.npy')
mask = np.load('/home/rt2122/Data/Planck/check_gen/y/6.npy')

# %%
plt.imshow(pic[:,:,:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(mask[:,:,0])

# %%
n_patches = 90000 // 40
idx = 0
n_patches
# Out:
# 2250

# %%
for pix in tqdm(train_pix):
    idx = gen_data_in_one_pix(pix, n_patches, 
        clusters, idx)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))

# %%
n_patches = 12000 // len(val_pix)
idx = 0
n_patches
# Out:
# 4000

# %%
for pix in tqdm(val_pix):
    idx = gen_data_in_one_pix(pix, n_patches, 
        clusters, idx, 
        outpath='/home/rt2122/Data/Planck/val_act')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))

# %%
n_patches = 4000
idx = 0

# %%
for pix in tqdm(test_pix):
    idx = gen_data_in_one_pix(pix, n_patches, 
        clusters, idx, 
        outpath='/home/rt2122/Data/Planck/test_act')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
def gen_data_from_pregen(path, batch_size):
    import os
    import numpy as np
    from tensorflow import convert_to_tensor
    
    n_pics = len(next(os.walk(os.path.join(path, 'x')))[-1])
    idx_sh = np.arange(n_pics)
    np.random.shuffle(idx_sh)
    for st in range(0, n_pics, batch_size):
        x = []
        y = []
        for idx in idx_sh[st:st+batch_size]:
            x.append(np.load(os.path.join(path, 'x', str(idx)) + '.npy'))
            y.append(np.load(os.path.join(path, 'y', str(idx)) + '.npy'))
        yield convert_to_tensor(np.stack(x)), convert_to_tensor(np.stack(y))

# %%
train_gen = gen_data_from_pregen('/home/rt2122/Data/Planck/train_act/', 1)

# %%
check_gen(train_gen)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
for pic, mask in train_gen:
    if mask.shape[-1] > 1:
        print('#', end='')

# %%
print(len(next(os.walk('/home/rt2122/Data/Planck/train/x/'))[-1]))
print(len(next(os.walk('/home/rt2122/Data/Planck/val/x/'))[-1]))
print(len(next(os.walk('/home/rt2122/Data/Planck/test/x/'))[-1]))
# Out:
# 97582
# 12000
# 4000

# %%
97582 / 20, 12000 / 20
# Out:
# (4879.1, 600.0)

# %%
dirname = '/home/rt2122/Data/Planck/val_act/y/'
files = next(os.walk(dirname))[-1]
count = 0
m = None
for file in tqdm(files):
    mask = np.load(os.path.join(dirname, file))
    if np.count_nonzero(mask) == 0:
        m = mask
        print(file)
        break
    if np.count_nonzero(np.isnan(mask)) > 0:
        m = mask
        print(file)
        break
    if np.count_nonzero(np.isinf(mask)) > 0:
        m = mask
        print(file)
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12000.0), HTML(value='')))

# %%
count
# Out:
# 0

# %%
np.isnan(np.array([1, np.nan]))
# Out:
# array([False,  True])

# %%
np.isinf

# %%
idx = [135140,
62670,
80282,
53427,
103487,
53549,
174665,
19734,
147433,
85028,
154355,
174024,
22877,
146772,
150578,
95689,
20260,
71424,
138579]

# %%
for i in idx:
    mask = np.load('/home/rt2122/Data/Planck/train_act/y/' + str(i) + '.npy')
    print(mask.min(), mask.max())
# Out:
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True

# %%
idx = [83851,
95551,
68455,
153556,
41962,
49127,
41512,
47710,
8058,
118618,
132159,
98684,
75767,
101153,
11369,
151282,
3453,
57601,
29225]
