# %%
from DS_WCS_projections import *
import numpy as np
from astropy.io import fits
from skimage.filters import gaussian

# %%
pic = np.zeros((2048, 2048, 3), dtype=np.float32)

# %%
with fits.open('/home/rt2122/Data/coma_sweep/south/sweep-190p025-200p030.fits') as hdul:
    data = hdul[1].data
    ra = data['RA']
    dec = data['DEC']
    pixels = ra_dec2pixels(194.8984, 27.9580, ra, dec)
    draw_data(pic, channels_data=(data['FLUX_G'], data['FLUX_R'], data['FLUX_Z']), 
              pixels=pixels.T, func=lambda x, y: x + y)
# Out:
# WARNING: FITSFixedWarning: 'cdfix' made the change 'Success'. [astropy.wcs.wcs]

# %%
show_pic(pic)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
gpic = gaussian(pic, 50)
# Out:
# <ipython-input-6-4fd37077206d>:1: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   gpic = gaussian(pic, 50)

# %%
show_pic(gpic)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
