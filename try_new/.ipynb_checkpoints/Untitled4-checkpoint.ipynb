# %%
import numpy as np
import pandas as pd
from DS_detector import rematch_cat
from astropy.io import fits
import healpy as hp
from DS_data_transformation import normalize

# %%
a = pd.Series([1, 1, 2, 4, 5, 6, 7, 8, 10, 11, 14, 15])

# %%
for i in np.arange(0, 1.1, 0.1):
    print(a.quantile(i))
# Out:
# 1.0
# 1.1
# 2.4000000000000004
# 4.300000000000001
# 5.4
# 6.5
# 7.600000000000001
# 9.399999999999999
# 10.8
# 13.700000000000001
# 15.0

# %%
rematch_cat('/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8.csv').to_csv(
    '/home/rt2122/Data/detected_cats/full_pz_all_found34_thr0.1_step8.csv', index=False)
# Out:
# /home/rt2122/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data = None
with fits.open('/home/rt2122/Data/Planck/y/nilc_ymaps.fits') as hdul:
    print(repr(hdul[1].header))
    data = np.array(hdul[1].data['FULL'])
# Out:
# XTENSION= 'BINTABLE'           /Written by IDL:  Sun Feb  1 15:05:26 2015
# BITPIX  =                    8 /
# NAXIS   =                    2 /Binary table
# NAXIS1  =                   16 /Number of bytes per row
# NAXIS2  =             50331648 /Number of rows
# PCOUNT  =                    0 /Random parameter count
# GCOUNT  =                    1 /Group count
# TFIELDS =                    4 /Number of columns
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# EXTVER  =                    1 /Extension version
# DATE    = '2015-02-01'         /Creation date
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'FULL    '           /
# TTYPE2  = 'FIRST   '           /
# TTYPE3  = 'LAST    '           /
# TTYPE4  = 'MASK    '           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = 'E       '           /
# TFORM2  = 'E       '           /
# TFORM3  = 'E       '           /
# TFORM4  = 'J       '           /
# COMMENT
# ...

# %%
data -= np.mean(data)
data /= np.std(data)

# %%
hp.mollview(data > 0)

# %%
n_data = hp.reorder(data, r2n=True)

# %%
hp.mollview(n_data > 0, nest=True)

# %%
np.save('/home/rt2122/Data/Planck/normalized/y/nilc.npy', n_data)

# %%
n_data.min(), n_data.max()
# Out:
# (-242.15526, 145.12961)

# %%
n_data -= np.mean(n_data)
n_data /= np.std(n_data)
n_data.min(), n_data.max()
# Out:
# (-242.15506, 145.12949)
