# %%
from astropy.io import fits
import numpy as np
from astropy.wcs import WCS
from matplotlib import pyplot as plt

# %%
hdul = fits.open('/home/rt2122/Downloads/cutout_194.9647_28.0091.fits')

# %%
wcs = WCS(hdul[0].header)
# Out:
# WARNING: FITSFixedWarning: 'cdfix' made the change 'Success'. [astropy.wcs.wcs]

# %%
data = hdul[0].data

# %%
data.shape
# Out:
# (3, 256, 256)

# %%
plt.imshow(np.dstack(list(data)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
wcs
# Out:
# WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'RA---TAN'  'DEC--TAN'  ''
# CRVAL : 194.9647  28.0091  0.0
# CRPIX : 128.5  128.5  0.0
# CD1_1 CD1_2 CD1_3  : -0.00111111111111111  0.0  0.0
# CD2_1 CD2_2 CD2_3  : 0.0  0.00111111111111111  0.0
# CD3_1 CD3_2 CD3_3  : 0.0  0.0  1.0
# NAXIS : 256  256  3
