# %%
import numpy as np
from DS_Planck_Unet import *
from DS_healpix_fragmentation import *
import healpy as hp
from matplotlib import pyplot as plt

# %%
batch_size = 20
min_rad = 0.08

# %%
train_gen = gen_data('/home/rt2122/Data/clusters/planck_z.csv', train_pix, 1, 
                    search_nside=256, min_rad=min_rad)

# %%
check_gen(train_gen)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
check_gen(train_gen)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
check_gen(train_gen)
# Out:
# (1, 64, 64, 6) (1, 64, 64, 1)

# %%
matr = one_pixel_fragmentation(2, 6, 10)[:64,:64]

# %%
matr[32,32]
mdict = matr2dict(matr)

# %%
pix2radec(6294528, 2048)
# Out:
# (314.37865388443015, 78.54428828924586)

# %%
small_circle = draw_proper_circle(314.37865388443015, 78.54428828924586, 0.08, 2048, 
                               mdict, (64,64), coords_mode=False)
normal_circle = draw_proper_circle(314.37865388443015, 78.54428828924586, 0.8, 2048, 
                               mdict, (64,64), coords_mode=False)

# %%
_, ax = plt.subplots(1, 2)
ax[0].matshow(small_circle)
ax[1].matshow(normal_circle)
