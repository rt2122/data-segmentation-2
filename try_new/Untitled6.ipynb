# %%
from scipy import signal
from matplotlib import pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

# %%
pic = imread('/home/rt2122/Desktop/%3F%3F%3F%3F%3F%3F.jpg')
pic = resize(pic, [10, 10])

# %%
window = signal.parzen(3)
_, ax = plt.subplots(1, 1, figsize=(10, 10))
ans = [0,
1/6,
1/3,
2/3,
3/4,
1]
for a, c in zip(ans, ['red', 'orange', 'yellow', 'green', 'blue', 'violet']):
    ax.axhline(a, c=c)
ax.axvline(1.5, c='k')
ax.plot([1, 2, 3], window)

# %%
window
# Out:
# array([0.07407407, 1.        , 0.07407407])
