# %%
import numpy as np
import healpy as hp

# %%
data = np.load('/home/rt2122/Data/Planck/normalized/100.npy')

# %%
hp.mollview(data, nest=True)

# %%
a = np.zeros(hp.nside2npix(1))
a[[0,1,5]]=np.arange(3)+1

# %%
hp.mollview(a, nest=True)
